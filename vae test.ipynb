# %%
import numpy as np
import pandas as pd

import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, models, transforms
from torch.utils.data.sampler import SubsetRandomSampler

import matplotlib.pyplot as plt
import time
import copy
from random import shuffle

import tqdm.notebook as tqdm

import sklearn
from sklearn.metrics import accuracy_score, cohen_kappa_score
from sklearn.metrics import classification_report
from PIL import Image
import cv2

# import osa
import shutil
import seaborn as sns
import os
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import torchvision
from glob import glob
from sklearn.metrics import roc_curve,auc, precision_score,precision_recall_curve,recall_score,precision_recall_fscore_support,confusion_matrix
import numpy as np
from sklearn.model_selection import train_test_split
from torchvision import models
from prettytable import PrettyTable
print(torch.cuda.is_available())
import warnings
warnings.filterwarnings("ignore")
# import pandas as pd
print(torch.cuda.get_device_properties(0).total_memory)
print(torch.cuda.memory_allocated())
# gpu_id = gpu
# Out:
# True
# 11721506816
# 0

# %%
from ray import tune

# %%
class objective(nn.Module):
    def __init__ (self,l1=1,l2=1):
        super(objective, self).__init__()
        self.l1=l1
        self.l2=l2
        

    def forward(self, x):
        x+= self.l1 + self.l2
        return x

# %%
config={
    # 'l1' : tune.choice([3,4,5]),
    'l1': tune.grid_search([3,4,5]),
    'l2': tune.grid_search([2,1,9])
    # 'l2' : tune.choice([2,1,9])
}

# %%
obj=objective( 3,4)
x=obj(3)

# %%
x
# Out:
# 10

# %%
def trainable(config):
    # config (dict): A dict of hyperparameters.

    for x in range(10):
        item= objective( config["l1"], config["l2"])
        intermediate_score=item(x)
        print(x,": ",intermediate_score)

        it=tune.report(score=intermediate_score)  # This sends the score to Tune.

# %%
# config={'l1': 2, "l2": 3}
# trainable(config)

# %%
# analysis.best_trial(metric="score", mode="max")

# %%
import pandas as pd

# %%
# all_dataframes['/DATA/chowdari1/ray_results/trainable_2022-02-09_05-25-28/trainable_97455_00000_0_2022-02-09_05-25-28']

# %%
# df

# %%
s
# Out:
# {'l1': 3, 'l2': 1}

# %%
s
# Out:
# {'l1': 3, 'l2': 1}

# %%
analysis = tune.run(
    trainable,
    config=config
)
s=analysis.get_best_config(metric="score", mode="min")
print("best config: ", analysis.get_best_config(metric="score", mode="min"))
df = analysis.dataframe(metric="score", mode="min")
all_dataframes = analysis.trial_dataframes
print('heloo------------------')
# Out:
# 2022-02-09 05:43:41,975	WARNING tune.py:580 -- Tune detects GPUs, but no trials are using GPUs. To enable trials to use GPUs, set tune.run(resources_per_trial={'gpu': 1}...) which allows Tune to expose 1 GPU to each trial. You can also override `Trainable.default_resource_request` if using the Trainable API.
# == Status ==<br>Current time: 2022-02-09 05:43:43 (running for 00:00:01.56)<br>Memory usage on this node: 114.7/251.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/48 CPUs, 0/8 GPUs, 0.0/89.66 GiB heap, 0.0/42.42 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /DATA/chowdari1/ray_results/trainable_2022-02-09_05-43-41<br>Number of trials: 9/9 (8 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc               </th><th style="text-align: right;">  l1</th><th style="text-align: right;">  l2</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_2349a_00000</td><td>RUNNING </td><td>172.25.0.208:17701</td><td style="text-align: right;">   3</td><td style="text-align: right;">   2</td></tr>
# <tr><td>trainable_2349a_00001</td><td>PENDING </td><td>                  </td><td style="text-align: right;">   4</td><td style="text-align: right;">   2</td></tr>
# <tr><td>trainable_2349a_00002</td><td>PENDING </td><td>                  </td><td style="text-align: right;">   5</td><td style="text-align: right;">   2</td></tr>
# <tr><td>trainable_2349a_00003</td><td>PENDING </td><td>                  </td><td style="text-align: right;">   3</td><td style="text-align: right;">   1</td></tr>
# <tr><td>trainable_2349a_00004</td><td>PENDING </td><td>                  </td><td style="text-align: right;">   4</td><td style="text-align: right;">   1</td></tr>
# <tr><td>trainable_2349a_00005</td><td>PENDING </td><td>                  </td><td style="text-align: right;">   5</td><td style="text-align: right;">   1</td></tr>
# <tr><td>trainable_2349a_00006</td><td>PENDING </td><td>                  </td><td style="text-align: right;">   3</td><td style="text-align: right;">   9</td></tr>
# <tr><td>trainable_2349a_00007</td><td>PENDING </td><td>                  </td><td style="text-align: right;">   4</td><td style="text-align: right;">   9</td></tr>
# <tr><td>trainable_2349a_00008</td><td>PENDING </td><td>                  </td><td style="text-align: right;">   5</td><td style="text-align: right;">   9</td></tr>
# </tbody>
# </table><br><br>
# (trainable pid=17701) 0 :  5
# Result for trainable_2349a_00000:
#   date: 2022-02-09_05-43-43
#   done: false
#   experiment_id: 2261404e0bc4442090189313972ae9b7
#   hostname: BOSS8-OS
#   iterations_since_restore: 1
#   node_ip: 172.25.0.208
#   pid: 17701
#   score: 5
#   time_since_restore: 0.00036644935607910156
#   time_this_iter_s: 0.00036644935607910156
#   time_total_s: 0.00036644935607910156
#   timestamp: 1644365623
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 2349a_00000
#
# Result for trainable_2349a_00000:
#   date: 2022-02-09_05-43-43
#   done: true
#   experiment_id: 2261404e0bc4442090189313972ae9b7
#   experiment_tag: 0_l1=3,l2=2
#   hostname: BOSS8-OS
#   iterations_since_restore: 10
#   node_ip: 172.25.0.208
#   pid: 17701
#   score: 14
#   time_since_restore: 0.12414193153381348
#   time_this_iter_s: 0.0024552345275878906
#   time_total_s: 0.12414193153381348
#   timestamp: 1644365623
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 2349a_00000
#
# (trainable pid=17701) 1 :  6
# (trainable pid=17701) 2 :  7
# (trainable pid=17701) 3 :  8
# (trainable pid=17701) 4 :  9
# (trainable pid=17701) 5 :  10
# (trainable pid=17701) 6 :  11
# (trainable pid=17701) 7 :  12
# (trainable pid=17701) 8 :  13
# (trainable pid=17701) 9 :  14
# Result for trainable_2349a_00006:
#   date: 2022-02-09_05-43-45
#   done: false
#   experiment_id: 59ed88210f484042b1cf1a136cab3b7d
#   hostname: BOSS8-OS
#   iterations_since_restore: 1
#   node_ip: 172.25.0.208
#   pid: 17745
#   score: 12
#   time_since_restore: 0.0007309913635253906
#   time_this_iter_s: 0.0007309913635253906
#   time_total_s: 0.0007309913635253906
#   timestamp: 1644365625
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 2349a_00006
#
# Result for trainable_2349a_00003:
#   date: 2022-02-09_05-43-45
#   done: false
#   experiment_id: 9ebea68fd2a34c84abfb65cef751f559
#   hostname: BOSS8-OS
#   iterations_since_restore: 1
#   node_ip: 172.25.0.208
#   pid: 17738
#   score: 4
#   time_since_restore: 0.0028548240661621094
#   time_this_iter_s: 0.0028548240661621094
#   time_total_s: 0.0028548240661621094
#   timestamp: 1644365625
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 2349a_00003
#
# Result for trainable_2349a_00002:
#   date: 2022-02-09_05-43-45
#   done: false
#   experiment_id: 6bc9fc0c8f514b4e9851aa8f7ea31150
#   hostname: BOSS8-OS
#   iterations_since_restore: 1
#   node_ip: 172.25.0.208
#   pid: 17692
#   score: 7
#   time_since_restore: 0.0006220340728759766
#   time_this_iter_s: 0.0006220340728759766
#   time_total_s: 0.0006220340728759766
#   timestamp: 1644365625
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 2349a_00002
#
# (trainable pid=17692) 0 :  7
# (trainable pid=17692) 1 :  8
# (trainable pid=17692) 2 :  9
# (trainable pid=17745) 0 :  12
# (trainable pid=17745) 1 :  13
# (trainable pid=17745) 2 :  14
# (trainable pid=17745) 3 :  15
# (trainable pid=17745) 4 :  16
# (trainable pid=17745) 5 :  17
# (trainable pid=17745) 6 :  18
# (trainable pid=17738) 0 :  4
# (trainable pid=17738) 1 :  5
# (trainable pid=17738) 2 :  6
# (trainable pid=17738) 3 :  7
# (trainable pid=17738) 4 :  8
# (trainable pid=17738) 5 :  9
# (trainable pid=17738) 6 :  10
# (trainable pid=17738) 7 :  11
# (trainable pid=17692) 3 :  10
# (trainable pid=17745) 7 :  19
# (trainable pid=17738) 8 :  12Result for trainable_2349a_00004:
#
#   date: 2022-02-09_05-43-45
#   done: false
#   experiment_id: f7d58c71823340789d84524bea278ef7
#   hostname: BOSS8-OS
#   iterations_since_restore: 1
#   node_ip: 172.25.0.208
#   pid: 17698
#   score: 5
#   time_since_restore: 0.000446319580078125
#   time_this_iter_s: 0.000446319580078125
#   time_total_s: 0.000446319580078125
#   timestamp: 1644365625
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 2349a_00004
#
# Result for trainable_2349a_00005:
#   date: 2022-02-09_05-43-45
#   done: false
#   experiment_id: 54d50c973dc141e191ceec394861f88a
#   hostname: BOSS8-OS
#   iterations_since_restore: 1
#   node_ip: 172.25.0.208
#   pid: 17733
#   score: 6
#   time_since_restore: 0.00040411949157714844
#   time_this_iter_s: 0.00040411949157714844
#   time_total_s: 0.00040411949157714844
#   timestamp: 1644365625
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 2349a_00005
#
# Result for trainable_2349a_00001:
#   date: 2022-02-09_05-43-45
#   done: false
#   experiment_id: bca977ccbede4025be606cdf2ce6d166
#   hostname: BOSS8-OS
#   iterations_since_restore: 1
#   node_ip: 172.25.0.208
#   pid: 17752
#   score: 6
#   time_since_restore: 0.008092641830444336
#   time_this_iter_s: 0.008092641830444336
#   time_total_s: 0.008092641830444336
#   timestamp: 1644365625
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 2349a_00001
#
# Result for trainable_2349a_00008:
#   date: 2022-02-09_05-43-45
#   done: false
#   experiment_id: 73910edae1df4bada82b9c55f4ea7a07
#   hostname: BOSS8-OS
#   iterations_since_restore: 1
#   node_ip: 172.25.0.208
#   pid: 17712
#   score: 14
#   time_since_restore: 0.000591278076171875
#   time_this_iter_s: 0.000591278076171875
#   time_total_s: 0.000591278076171875
#   timestamp: 1644365625
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 2349a_00008
#
# Result for trainable_2349a_00003:
#   date: 2022-02-09_05-43-45
#   done: true
#   experiment_id: 9ebea68fd2a34c84abfb65cef751f559
#   experiment_tag: 3_l1=3,l2=1
#   hostname: BOSS8-OS
#   iterations_since_restore: 10
#   node_ip: 172.25.0.208
#   pid: 17738
#   score: 13
#   time_since_restore: 0.0936439037322998
#   time_this_iter_s: 0.018674135208129883
#   time_total_s: 0.0936439037322998
#   timestamp: 1644365625
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 2349a_00003
#
# Result for trainable_2349a_00007:
#   date: 2022-02-09_05-43-45
#   done: false
#   experiment_id: 1cabddd2aff94dc8a65b711ffcfa72a1
#   hostname: BOSS8-OS
#   iterations_since_restore: 1
#   node_ip: 172.25.0.208
#   pid: 17767
#   score: 13
#   time_since_restore: 0.0004112720489501953
#   time_this_iter_s: 0.0004112720489501953
#   time_total_s: 0.0004112720489501953
#   timestamp: 1644365625
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 2349a_00007
#
# (trainable pid=17692) 4 :  11
# (trainable pid=17692) 5 :  12
# (trainable pid=17733) 0 :  6
# (trainable pid=17733) 1 :  7
# (trainable pid=17698) 0 :  5
# (trainable pid=17698) 1 :  6
# (trainable pid=17698) 2 :  7
# (trainable pid=17698) 3 :  8
# (trainable pid=17698) 4 :  9
# (trainable pid=17745) 8 :  20
# (trainable pid=17738) 9 :  13
# (trainable pid=17752) 0 :  6
# (trainable pid=17752) 1 :  7
# (trainable pid=17752) 2 :  8
# (trainable pid=17752) 3 :  9
# (trainable pid=17752) 4 :  10
# (trainable pid=17752) 5 :  11
# (trainable pid=17712) 0 :  14
# (trainable pid=17712) 1 :  15
# (trainable pid=17767) 0 :  13
# (trainable pid=17698) 5 :  10
# (trainable pid=17767) 1 :  14
# Result for trainable_2349a_00004:
#   date: 2022-02-09_05-43-45
#   done: true
#   experiment_id: f7d58c71823340789d84524bea278ef7
#   experiment_tag: 4_l1=4,l2=1
#   hostname: BOSS8-OS
#   iterations_since_restore: 10
#   node_ip: 172.25.0.208
#   pid: 17698
#   score: 14
#   time_since_restore: 0.14357757568359375
#   time_this_iter_s: 0.016679048538208008
#   time_total_s: 0.14357757568359375
#   timestamp: 1644365625
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 2349a_00004
#
# Result for trainable_2349a_00006:
#   date: 2022-02-09_05-43-45
#   done: true
#   experiment_id: 59ed88210f484042b1cf1a136cab3b7d
#   experiment_tag: 6_l1=3,l2=9
#   hostname: BOSS8-OS
#   iterations_since_restore: 10
#   node_ip: 172.25.0.208
#   pid: 17745
#   score: 21
#   time_since_restore: 0.27660703659057617
#   time_this_iter_s: 0.17160367965698242
#   time_total_s: 0.27660703659057617
#   timestamp: 1644365625
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 2349a_00006
#
# Result for trainable_2349a_00001:
#   date: 2022-02-09_05-43-45
#   done: true
#   experiment_id: bca977ccbede4025be606cdf2ce6d166
#   experiment_tag: 1_l1=4,l2=2
#   hostname: BOSS8-OS
#   iterations_since_restore: 10
#   node_ip: 172.25.0.208
#   pid: 17752
#   score: 15
#   time_since_restore: 0.17648601531982422
#   time_this_iter_s: 0.010625123977661133
#   time_total_s: 0.17648601531982422
#   timestamp: 1644365625
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 2349a_00001
#
# (trainable pid=17692) 6 :  13
# (trainable pid=17692) 7 :  14
# (trainable pid=17692) 8 :  15
# (trainable pid=17692) 9 :  16
# (trainable pid=17733) 2 :  8
# (trainable pid=17698) 6 :  11
# (trainable pid=17698) 7 :  12
# (trainable pid=17698) 8 :  13
# (trainable pid=17698) 9 :  14
# (trainable pid=17745) 9 :  21
# (trainable pid=17752) 6 :  12
# (trainable pid=17752) 7 :  13
# (trainable pid=17752) 8 :  14
# (trainable pid=17752) 9 :  15
# (trainable pid=17712) 2 :  16
# (trainable pid=17712) 3 :  17
# (trainable pid=17712) 4 :  18
# (trainable pid=17712) 5 :  19
# (trainable pid=17767) 2 :  15
# (trainable pid=17767) 3 :  16
# (trainable pid=17767) 4 :  17
# (trainable pid=17767) 5 :  18
# Result for trainable_2349a_00002:
#   date: 2022-02-09_05-43-45
#   done: true
#   experiment_id: 6bc9fc0c8f514b4e9851aa8f7ea31150
#   experiment_tag: 2_l1=5,l2=2
#   hostname: BOSS8-OS
#   iterations_since_restore: 10
#   node_ip: 172.25.0.208
#   pid: 17692
#   score: 16
#   time_since_restore: 0.2240889072418213
#   time_this_iter_s: 0.02823042869567871
#   time_total_s: 0.2240889072418213
#   timestamp: 1644365625
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 2349a_00002
#
# Result for trainable_2349a_00007:
#   date: 2022-02-09_05-43-45
#   done: true
#   experiment_id: 1cabddd2aff94dc8a65b711ffcfa72a1
#   experiment_tag: 7_l1=4,l2=9
#   hostname: BOSS8-OS
#   iterations_since_restore: 10
#   node_ip: 172.25.0.208
#   pid: 17767
#   score: 22
#   time_since_restore: 0.21063613891601562
#   time_this_iter_s: 0.006506204605102539
#   time_total_s: 0.21063613891601562
#   timestamp: 1644365625
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 2349a_00007
#
# Result for trainable_2349a_00005:
#   date: 2022-02-09_05-43-45
#   done: true
#   experiment_id: 54d50c973dc141e191ceec394861f88a
#   experiment_tag: 5_l1=5,l2=1
#   hostname: BOSS8-OS
#   iterations_since_restore: 10
#   node_ip: 172.25.0.208
#   pid: 17733
#   score: 15
#   time_since_restore: 0.2623274326324463
#   time_this_iter_s: 0.007580757141113281
#   time_total_s: 0.2623274326324463
#   timestamp: 1644365625
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 2349a_00005
#
# Result for trainable_2349a_00008:
#   date: 2022-02-09_05-43-45
#   done: true
#   experiment_id: 73910edae1df4bada82b9c55f4ea7a07
#   experiment_tag: 8_l1=5,l2=9
#   hostname: BOSS8-OS
#   iterations_since_restore: 10
#   node_ip: 172.25.0.208
#   pid: 17712
#   score: 23
#   time_since_restore: 0.27043819427490234
#   time_this_iter_s: 0.002598285675048828
#   time_total_s: 0.27043819427490234
#   timestamp: 1644365625
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 2349a_00008
#
# (trainable pid=17733) 3 :  9
# (trainable pid=17733) 4 :  10
# (trainable pid=17733) 5 :  11
# (trainable pid=17733) 6 :  12
# (trainable pid=17733) 7 :  13
# (trainable pid=17733) 8 :  14
# (trainable pid=17733) 9 :  15
# (trainable pid=17712) 6 :  20
# (trainable pid=17712) 7 :  21
# (trainable pid=17712) 8 :  22
# (trainable pid=17712) 9 :  23
# (trainable pid=17767) 6 :  19
# (trainable pid=17767) 7 :  20
# (trainable pid=17767) 8 :  21
# (trainable pid=17767) 9 :  22
# == Status ==<br>Current time: 2022-02-09 05:43:45 (running for 00:00:03.54)<br>Memory usage on this node: 114.3/251.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/48 CPUs, 0/8 GPUs, 0.0/89.66 GiB heap, 0.0/42.42 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /DATA/chowdari1/ray_results/trainable_2022-02-09_05-43-41<br>Number of trials: 9/9 (9 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status    </th><th>loc               </th><th style="text-align: right;">  l1</th><th style="text-align: right;">  l2</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  score</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_2349a_00000</td><td>TERMINATED</td><td>172.25.0.208:17701</td><td style="text-align: right;">   3</td><td style="text-align: right;">   2</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.124142 </td><td style="text-align: right;">     14</td></tr>
# <tr><td>trainable_2349a_00001</td><td>TERMINATED</td><td>172.25.0.208:17752</td><td style="text-align: right;">   4</td><td style="text-align: right;">   2</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.176486 </td><td style="text-align: right;">     15</td></tr>
# <tr><td>trainable_2349a_00002</td><td>TERMINATED</td><td>172.25.0.208:17692</td><td style="text-align: right;">   5</td><td style="text-align: right;">   2</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.224089 </td><td style="text-align: right;">     16</td></tr>
# <tr><td>trainable_2349a_00003</td><td>TERMINATED</td><td>172.25.0.208:17738</td><td style="text-align: right;">   3</td><td style="text-align: right;">   1</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.0936439</td><td style="text-align: right;">     13</td></tr>
# <tr><td>trainable_2349a_00004</td><td>TERMINATED</td><td>172.25.0.208:17698</td><td style="text-align: right;">   4</td><td style="text-align: right;">   1</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.143578 </td><td style="text-align: right;">     14</td></tr>
# <tr><td>trainable_2349a_00005</td><td>TERMINATED</td><td>172.25.0.208:17733</td><td style="text-align: right;">   5</td><td style="text-align: right;">   1</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.262327 </td><td style="text-align: right;">     15</td></tr>
# <tr><td>trainable_2349a_00006</td><td>TERMINATED</td><td>172.25.0.208:17745</td><td style="text-align: right;">   3</td><td style="text-align: right;">   9</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.276607 </td><td style="text-align: right;">     21</td></tr>
# <tr><td>trainable_2349a_00007</td><td>TERMINATED</td><td>172.25.0.208:17767</td><td style="text-align: right;">   4</td><td style="text-align: right;">   9</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.210636 </td><td style="text-align: right;">     22</td></tr>
# <tr><td>trainable_2349a_00008</td><td>TERMINATED</td><td>172.25.0.208:17712</td><td style="text-align: right;">   5</td><td style="text-align: right;">   9</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.270438 </td><td style="text-align: right;">     23</td></tr>
# </tbody>
# </table><br><br>
# 2022-02-09 05:43:45,633	INFO tune.py:636 -- Total run time: 3.68 seconds (3.51 seconds for the tuning loop).
# best config:  {'l1': 3, 'l2': 1}
# heloo------------------

# %%
analysis = tune.run(
    trainable,
    config=config
)
s=analysis.get_best_config(metric="score", mode="min")
print("best config: ", analysis.get_best_config(metric="score", mode="max"))
# df = analysis.dataframe(metric="score", mode="min")
all_dataframes = analysis.trial_dataframes
print('heloo------------------')
# Out:
# 2022-02-09 05:37:02,131	WARNING tune.py:580 -- Tune detects GPUs, but no trials are using GPUs. To enable trials to use GPUs, set tune.run(resources_per_trial={'gpu': 1}...) which allows Tune to expose 1 GPU to each trial. You can also override `Trainable.default_resource_request` if using the Trainable API.
# == Status ==<br>Current time: 2022-02-09 05:37:03 (running for 00:00:01.66)<br>Memory usage on this node: 114.8/251.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/48 CPUs, 0/8 GPUs, 0.0/89.66 GiB heap, 0.0/42.42 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /DATA/chowdari1/ray_results/trainable_2022-02-09_05-37-02<br>Number of trials: 9/9 (8 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc               </th><th style="text-align: right;">  l1</th><th style="text-align: right;">  l2</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_34f68_00000</td><td>RUNNING </td><td>172.25.0.208:17760</td><td style="text-align: right;">   3</td><td style="text-align: right;">   2</td></tr>
# <tr><td>trainable_34f68_00001</td><td>PENDING </td><td>                  </td><td style="text-align: right;">   4</td><td style="text-align: right;">   2</td></tr>
# <tr><td>trainable_34f68_00002</td><td>PENDING </td><td>                  </td><td style="text-align: right;">   5</td><td style="text-align: right;">   2</td></tr>
# <tr><td>trainable_34f68_00003</td><td>PENDING </td><td>                  </td><td style="text-align: right;">   3</td><td style="text-align: right;">   1</td></tr>
# <tr><td>trainable_34f68_00004</td><td>PENDING </td><td>                  </td><td style="text-align: right;">   4</td><td style="text-align: right;">   1</td></tr>
# <tr><td>trainable_34f68_00005</td><td>PENDING </td><td>                  </td><td style="text-align: right;">   5</td><td style="text-align: right;">   1</td></tr>
# <tr><td>trainable_34f68_00006</td><td>PENDING </td><td>                  </td><td style="text-align: right;">   3</td><td style="text-align: right;">   9</td></tr>
# <tr><td>trainable_34f68_00007</td><td>PENDING </td><td>                  </td><td style="text-align: right;">   4</td><td style="text-align: right;">   9</td></tr>
# <tr><td>trainable_34f68_00008</td><td>PENDING </td><td>                  </td><td style="text-align: right;">   5</td><td style="text-align: right;">   9</td></tr>
# </tbody>
# </table><br><br>
# (trainable pid=17760) 0 :  5
# Result for trainable_34f68_00000:
#   date: 2022-02-09_05-37-03
#   done: false
#   experiment_id: ca4be8cc210e432a8272ed891df6e182
#   hostname: BOSS8-OS
#   iterations_since_restore: 1
#   node_ip: 172.25.0.208
#   pid: 17760
#   score: 5
#   time_since_restore: 0.0005688667297363281
#   time_this_iter_s: 0.0005688667297363281
#   time_total_s: 0.0005688667297363281
#   timestamp: 1644365223
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 34f68_00000
#
# Result for trainable_34f68_00000:
#   date: 2022-02-09_05-37-03
#   done: true
#   experiment_id: ca4be8cc210e432a8272ed891df6e182
#   experiment_tag: 0_l1=3,l2=2
#   hostname: BOSS8-OS
#   iterations_since_restore: 10
#   node_ip: 172.25.0.208
#   pid: 17760
#   score: 14
#   time_since_restore: 0.08656883239746094
#   time_this_iter_s: 0.0043299198150634766
#   time_total_s: 0.08656883239746094
#   timestamp: 1644365223
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 34f68_00000
#
# (trainable pid=17760) 1 :  6
# (trainable pid=17760) 2 :  7
# (trainable pid=17760) 3 :  8
# (trainable pid=17760) 4 :  9
# (trainable pid=17760) 5 :  10
# (trainable pid=17760) 6 :  11
# (trainable pid=17760) 7 :  12
# (trainable pid=17760) 8 :  13
# (trainable pid=17760) 9 :  14
# Result for trainable_34f68_00004:
#   date: 2022-02-09_05-37-05
#   done: false
#   experiment_id: e00bf90b5d004db2898b90f660a8144a
#   hostname: BOSS8-OS
#   iterations_since_restore: 1
#   node_ip: 172.25.0.208
#   pid: 17790
#   score: 5
#   time_since_restore: 0.009294748306274414
#   time_this_iter_s: 0.009294748306274414
#   time_total_s: 0.009294748306274414
#   timestamp: 1644365225
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 34f68_00004
#
# Result for trainable_34f68_00001:
#   date: 2022-02-09_05-37-05
#   done: false
#   experiment_id: a40a84fd99f44a8a894f80a9c850dedf
#   hostname: BOSS8-OS
#   iterations_since_restore: 1
#   node_ip: 172.25.0.208
#   pid: 17715
#   score: 6
#   time_since_restore: 0.00038433074951171875
#   time_this_iter_s: 0.00038433074951171875
#   time_total_s: 0.00038433074951171875
#   timestamp: 1644365225
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 34f68_00001
#
# Result for trainable_34f68_00003:
#   date: 2022-02-09_05-37-05
#   done: false
#   experiment_id: cb8ca6d578d747728df9b5677cffd655
#   hostname: BOSS8-OS
#   iterations_since_restore: 1
#   node_ip: 172.25.0.208
#   pid: 17793
#   score: 4
#   time_since_restore: 0.00034689903259277344
#   time_this_iter_s: 0.00034689903259277344
#   time_total_s: 0.00034689903259277344
#   timestamp: 1644365225
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 34f68_00003
#
# Result for trainable_34f68_00006:
#   date: 2022-02-09_05-37-05
#   done: false
#   experiment_id: 1a62a2fe50b34dd2853f9ad07da727fc
#   hostname: BOSS8-OS
#   iterations_since_restore: 1
#   node_ip: 172.25.0.208
#   pid: 17697
#   score: 12
#   time_since_restore: 0.0003077983856201172
#   time_this_iter_s: 0.0003077983856201172
#   time_total_s: 0.0003077983856201172
#   timestamp: 1644365225
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 34f68_00006
#
# (trainable pid=17715) 0 :  6
# (trainable pid=17715) 1 :  7
# (trainable pid=17715) 2 :  8
# (trainable pid=17715) 3 :  9
# (trainable pid=17715) 4 :  10
# (trainable pid=17790) 0 :  5
# (trainable pid=17790) 1 :  6
# (trainable pid=17790) 2 :  7
# (trainable pid=17790) 3 :  8
# (trainable pid=17790) 4 :  9
# (trainable pid=17790) 5 :  10
# (trainable pid=17793) 0 :  4
# (trainable pid=17793) 1 :  5
# (trainable pid=17793) 2 :  6
# (trainable pid=17697) 0 :  12
# (trainable pid=17697) 1 :  13
# (trainable pid=17697) 2 :  14
# (trainable pid=17697) 3 :  15
# (trainable pid=17715) 5 :  11
# (trainable pid=17790) 6 :  11
# Result for trainable_34f68_00002:
#   date: 2022-02-09_05-37-05
#   done: false
#   experiment_id: fece057c1fd344c7aaf6daa9e9e23292
#   hostname: BOSS8-OS
#   iterations_since_restore: 1
#   node_ip: 172.25.0.208
#   pid: 17786
#   score: 7
#   time_since_restore: 0.000904083251953125
#   time_this_iter_s: 0.000904083251953125
#   time_total_s: 0.000904083251953125
#   timestamp: 1644365225
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 34f68_00002
#
# Result for trainable_34f68_00005:
#   date: 2022-02-09_05-37-05
#   done: false
#   experiment_id: ab54730bf73d41928662c2fb5f869eb2
#   hostname: BOSS8-OS
#   iterations_since_restore: 1
#   node_ip: 172.25.0.208
#   pid: 17815
#   score: 6
#   time_since_restore: 0.0012040138244628906
#   time_this_iter_s: 0.0012040138244628906
#   time_total_s: 0.0012040138244628906
#   timestamp: 1644365225
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 34f68_00005
#
# Result for trainable_34f68_00008:
#   date: 2022-02-09_05-37-05
#   done: false
#   experiment_id: 65ea8210b1ed481da137d3eb371684f4
#   hostname: BOSS8-OS
#   iterations_since_restore: 1
#   node_ip: 172.25.0.208
#   pid: 17776
#   score: 14
#   time_since_restore: 0.003252267837524414
#   time_this_iter_s: 0.003252267837524414
#   time_total_s: 0.003252267837524414
#   timestamp: 1644365225
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 34f68_00008
#
# (trainable pid=17786) 0 :  7
# (trainable pid=17786) 1 :  8
# (trainable pid=17786) 2 :  9
# (trainable pid=17715) 6 :  12
# (trainable pid=17715) 7 :  13
# (trainable pid=17715) 8 :  14
# (trainable pid=17776) 0 :  14
# (trainable pid=17776) 1 :  15
# (trainable pid=17790) 7 :  12
# (trainable pid=17790) 8 :  13
# (trainable pid=17793) 3 :  7
# (trainable pid=17793) 4 :  8
# (trainable pid=17793) 5 :  9
# (trainable pid=17793) 6 :  10
# (trainable pid=17793) 7 :  11
# (trainable pid=17697) 4 :  16
# (trainable pid=17697) 5 :  17
# (trainable pid=17697) 6 :  18
# (trainable pid=17815) 0 :  6
# (trainable pid=17815) 1 :  7
# (trainable pid=17815) 2 :  8
# (trainable pid=17815) 3 :  9
# (trainable pid=17776) 2 :  16
# Result for trainable_34f68_00007:
#   date: 2022-02-09_05-37-05
#   done: false
#   experiment_id: cc6c6ae343ad4f2bad6461f15cba42ad
#   hostname: BOSS8-OS
#   iterations_since_restore: 1
#   node_ip: 172.25.0.208
#   pid: 17696
#   score: 13
#   time_since_restore: 0.001556396484375
#   time_this_iter_s: 0.001556396484375
#   time_total_s: 0.001556396484375
#   timestamp: 1644365225
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 34f68_00007
#
# Result for trainable_34f68_00004:
#   date: 2022-02-09_05-37-05
#   done: true
#   experiment_id: e00bf90b5d004db2898b90f660a8144a
#   experiment_tag: 4_l1=4,l2=1
#   hostname: BOSS8-OS
#   iterations_since_restore: 10
#   node_ip: 172.25.0.208
#   pid: 17790
#   score: 14
#   time_since_restore: 0.23229575157165527
#   time_this_iter_s: 0.0979452133178711
#   time_total_s: 0.23229575157165527
#   timestamp: 1644365225
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 34f68_00004
#
# Result for trainable_34f68_00001:
#   date: 2022-02-09_05-37-05
#   done: true
#   experiment_id: a40a84fd99f44a8a894f80a9c850dedf
#   experiment_tag: 1_l1=4,l2=2
#   hostname: BOSS8-OS
#   iterations_since_restore: 10
#   node_ip: 172.25.0.208
#   pid: 17715
#   score: 15
#   time_since_restore: 0.20704436302185059
#   time_this_iter_s: 0.06140565872192383
#   time_total_s: 0.20704436302185059
#   timestamp: 1644365225
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 34f68_00001
#
# (trainable pid=17786) 3 :  10
# (trainable pid=17786) 4 :  11
# (trainable pid=17786) 5 :  12
# (trainable pid=17715) 9 :  15
# (trainable pid=17776) 3 :  17
# (trainable pid=17776) 4 :  18
# (trainable pid=17790) 9 :  14
# (trainable pid=17793) 8 :  12
# (trainable pid=17793) 9 :  13
# (trainable pid=17697) 7 :  19
# (trainable pid=17697) 8 :  20
# (trainable pid=17696) 0 :  13
# (trainable pid=17696) 1 :  14
# (trainable pid=17815) 4 :  10
# (trainable pid=17815) 5 :  11
# (trainable pid=17815) 6 :  12
# (trainable pid=17815) 7 :  13
# (trainable pid=17815) 8 :  14
# (trainable pid=17776) 5 :  19
# (trainable pid=17697) 9 :  21
# Result for trainable_34f68_00005:
#   date: 2022-02-09_05-37-05
#   done: true
#   experiment_id: ab54730bf73d41928662c2fb5f869eb2
#   experiment_tag: 5_l1=5,l2=1
#   hostname: BOSS8-OS
#   iterations_since_restore: 10
#   node_ip: 172.25.0.208
#   pid: 17815
#   score: 15
#   time_since_restore: 0.1778872013092041
#   time_this_iter_s: 0.004988670349121094
#   time_total_s: 0.1778872013092041
#   timestamp: 1644365225
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 34f68_00005
#
# Result for trainable_34f68_00008:
#   date: 2022-02-09_05-37-05
#   done: true
#   experiment_id: 65ea8210b1ed481da137d3eb371684f4
#   experiment_tag: 8_l1=5,l2=9
#   hostname: BOSS8-OS
#   iterations_since_restore: 10
#   node_ip: 172.25.0.208
#   pid: 17776
#   score: 23
#   time_since_restore: 0.23050951957702637
#   time_this_iter_s: 0.011388778686523438
#   time_total_s: 0.23050951957702637
#   timestamp: 1644365225
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 34f68_00008
#
# Result for trainable_34f68_00006:
#   date: 2022-02-09_05-37-05
#   done: true
#   experiment_id: 1a62a2fe50b34dd2853f9ad07da727fc
#   experiment_tag: 6_l1=3,l2=9
#   hostname: BOSS8-OS
#   iterations_since_restore: 10
#   node_ip: 172.25.0.208
#   pid: 17697
#   score: 21
#   time_since_restore: 0.28174710273742676
#   time_this_iter_s: 0.03006577491760254
#   time_total_s: 0.28174710273742676
#   timestamp: 1644365225
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 34f68_00006
#
# Result for trainable_34f68_00003:
#   date: 2022-02-09_05-37-05
#   done: true
#   experiment_id: cb8ca6d578d747728df9b5677cffd655
#   experiment_tag: 3_l1=3,l2=1
#   hostname: BOSS8-OS
#   iterations_since_restore: 10
#   node_ip: 172.25.0.208
#   pid: 17793
#   score: 13
#   time_since_restore: 0.18746399879455566
#   time_this_iter_s: 0.008975744247436523
#   time_total_s: 0.18746399879455566
#   timestamp: 1644365225
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 34f68_00003
#
# Result for trainable_34f68_00007:
#   date: 2022-02-09_05-37-05
#   done: true
#   experiment_id: cc6c6ae343ad4f2bad6461f15cba42ad
#   experiment_tag: 7_l1=4,l2=9
#   hostname: BOSS8-OS
#   iterations_since_restore: 10
#   node_ip: 172.25.0.208
#   pid: 17696
#   score: 22
#   time_since_restore: 0.16014480590820312
#   time_this_iter_s: 0.0051233768463134766
#   time_total_s: 0.16014480590820312
#   timestamp: 1644365225
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 34f68_00007
#
# Result for trainable_34f68_00002:(trainable pid=17786) 6 :  13
# (trainable pid=17786) 7 :  14
#   date: 2022-02-09_05-37-05
#   done: true
#   experiment_id: fece057c1fd344c7aaf6daa9e9e23292
#   experiment_tag: 2_l1=5,l2=2
#   hostname: BOSS8-OS
#   iterations_since_restore: 10
#   node_ip: 172.25.0.208
#   pid: 17786
#   score: 16
#   time_since_restore: 0.28868842124938965
#   time_this_iter_s: 0.015070676803588867
#   time_total_s: 0.28868842124938965
#   timestamp: 1644365225
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 34f68_00002
#
#
# (trainable pid=17786) 8 :  15
# (trainable pid=17786) 9 :  16
# (trainable pid=17776) 6 :  20
# (trainable pid=17776) 7 :  21
# (trainable pid=17776) 8 :  22
# (trainable pid=17776) 9 :  23
# (trainable pid=17696) 2 :  15
# (trainable pid=17696) 3 :  16
# (trainable pid=17696) 4 :  17
# (trainable pid=17696) 5 :  18
# (trainable pid=17696) 6 :  19
# (trainable pid=17696) 7 :  20
# (trainable pid=17696) 8 :  21
# (trainable pid=17696) 9 :  22
# (trainable pid=17815) 9 :  15
# == Status ==<br>Current time: 2022-02-09 05:37:05 (running for 00:00:03.60)<br>Memory usage on this node: 114.3/251.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/48 CPUs, 0/8 GPUs, 0.0/89.66 GiB heap, 0.0/42.42 GiB objects (0.0/1.0 accelerator_type:GTX)<br>Result logdir: /DATA/chowdari1/ray_results/trainable_2022-02-09_05-37-02<br>Number of trials: 9/9 (9 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status    </th><th>loc               </th><th style="text-align: right;">  l1</th><th style="text-align: right;">  l2</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  score</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_34f68_00000</td><td>TERMINATED</td><td>172.25.0.208:17760</td><td style="text-align: right;">   3</td><td style="text-align: right;">   2</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.0865688</td><td style="text-align: right;">     14</td></tr>
# <tr><td>trainable_34f68_00001</td><td>TERMINATED</td><td>172.25.0.208:17715</td><td style="text-align: right;">   4</td><td style="text-align: right;">   2</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.207044 </td><td style="text-align: right;">     15</td></tr>
# <tr><td>trainable_34f68_00002</td><td>TERMINATED</td><td>172.25.0.208:17786</td><td style="text-align: right;">   5</td><td style="text-align: right;">   2</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.288688 </td><td style="text-align: right;">     16</td></tr>
# <tr><td>trainable_34f68_00003</td><td>TERMINATED</td><td>172.25.0.208:17793</td><td style="text-align: right;">   3</td><td style="text-align: right;">   1</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.187464 </td><td style="text-align: right;">     13</td></tr>
# <tr><td>trainable_34f68_00004</td><td>TERMINATED</td><td>172.25.0.208:17790</td><td style="text-align: right;">   4</td><td style="text-align: right;">   1</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.232296 </td><td style="text-align: right;">     14</td></tr>
# <tr><td>trainable_34f68_00005</td><td>TERMINATED</td><td>172.25.0.208:17815</td><td style="text-align: right;">   5</td><td style="text-align: right;">   1</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.177887 </td><td style="text-align: right;">     15</td></tr>
# <tr><td>trainable_34f68_00006</td><td>TERMINATED</td><td>172.25.0.208:17697</td><td style="text-align: right;">   3</td><td style="text-align: right;">   9</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.281747 </td><td style="text-align: right;">     21</td></tr>
# <tr><td>trainable_34f68_00007</td><td>TERMINATED</td><td>172.25.0.208:17696</td><td style="text-align: right;">   4</td><td style="text-align: right;">   9</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.160145 </td><td style="text-align: right;">     22</td></tr>
# <tr><td>trainable_34f68_00008</td><td>TERMINATED</td><td>172.25.0.208:17776</td><td style="text-align: right;">   5</td><td style="text-align: right;">   9</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.23051  </td><td style="text-align: right;">     23</td></tr>
# </tbody>
# </table><br><br>
# 2022-02-09 05:37:05,849	INFO tune.py:636 -- Total run time: 3.74 seconds (3.57 seconds for the tuning loop).
# best config:  {'l1': 5, 'l2': 9}
# heloo------------------

# %%
from ray import tune
from ray.tune.examples.mnist_pytorch import get_data_loaders, ConvNet, train, test

from nltk.util import ngrams
from collections import defaultdict, Counter
import numpy as np
import math
import tqdm
import random

import torch
from torch import nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.nn import Parameter
import torchtext

##### XXX Note that we duplicate this data loading here because we need the vocab size to create the model
# download and load the data

text_field = torchtext.data.Field()
datasets = torchtext.datasets.WikiText2.splits(root='.', text_field=text_field)
train_dataset, validation_dataset, test_dataset = datasets
text_field.build_vocab(train_dataset)
vocab = text_field.vocab
vocab_size = len(vocab)

train_text = train_dataset.examples[0].text # a list of tokens (strings)
validation_text = validation_dataset.examples[0].text

import torch.optim as optim

#  ... other code 

class LSTMModel():
    #  ... other code 
    def train_on_dataset(self, dataset):
        train_iterator = torchtext.data.BPTTIterator(dataset, batch_size=64, 
                                                     bptt_len=32, device='cuda')
        ## THE REST OF THE CODE IS THE SAME AS YOUR `train` FUNCTION
        h = Variable(torch.zeros(3, 64, self.network.lstm.hidden_size), requires_grad=False).cuda()
        c = Variable(torch.zeros(3, 64, self.network.lstm.hidden_size), requires_grad=False).cuda()
        state = ( h, c )

        optimizer = torch.optim.Adam(self.network.parameters(), lr=self.lr)
        n_epochs = 20

        validation_score_best = 300
        PATH = '/content/model.pth'


        for epoch in range(n_epochs):
            print('Epoch', epoch)
            for batch in tqdm.tqdm_notebook(train_iterator, leave=False):
                assert self.network.training, 'make sure your network is in train mode with `.train()`'

                # call zero_grad on your optimizer
                optimizer.zero_grad()

                context, word = batch.text, batch.target
                # run your network
                logits, state = self.network(context, state)

                logits = logits.view(-1, logits.shape[-1])
                word = word.view(-1,)

                # compute a loss
                loss = F.cross_entropy(logits, word)

                # call `.backward()` and `.step()` on your optimizer
                loss.backward()
                optimizer.step()

            validation_score = self.dataset_perplexity(validation_dataset)
            print('Validation score:', validation_score)
            
            if validation_score <= validation_score_best:
                validation_score_best = validation_score
                torch.save(self.network.state_dict(), PATH)
        
        
        self.network.load_state_dict(torch.load(PATH))

def train_net(config):
    text_field = torchtext.data.Field()
    datasets = torchtext.datasets.WikiText2.splits(root='.', text_field=text_field)
    train_dataset, validation_dataset, test_dataset = datasets
    validation_text = validation_dataset.examples[0].text
    lstm_model = LSTMModel(config['lr'], config['clip'])
    lstm_model.train_on_dataset(train_dataset)
    perp = lstm_model.perplexity(validation_text)
    print('lstm validation perplexity:', perp)
    tune.track.log(perplexity=perp)


analysis = tune.run(
    train_net, config={"lr": tune.grid_search([0.001, 0.01]), 'clip':  tune.grid_search([0.001, 0.01])})

print("Best config: ", analysis.get_best_config(metric="mean_accuracy"))

# Get a dataframe for analyzing trial results.
df = analysis.dataframe()
# Out:
# downloading wikitext-2-v1.zip
# wikitext-2-v1.zip: 100%|██████████| 4.48M/4.48M [00:04<00:00, 1.10MB/s]
# extracting
# 2022-02-09 02:12:29,210	WARNING function_runner.py:562 -- Function checkpointing is disabled. This may result in unexpected behavior when using checkpointing features or certain schedulers. To enable, set the train function arguments to be `func(config, checkpoint_dir=None)`.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_10465/3350335783.py in <module>
#      95
#      96 analysis = tune.run(
# ---> 97     train_net, config={"lr": tune.grid_search([0.001, 0.01]), 'clip':  tune.grid_search([0.001, 0.01])})
#      98
#      99 print("Best config: ", analysis.get_best_config(metric="mean_accuracy"))
#
# ~/.local/lib/python3.7/site-packages/ray/tune/tune.py in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, local_dir, search_alg, scheduler, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, sync_config, export_formats, max_failures, fail_fast, restore, server_port, resume, reuse_actors, trial_executor, raise_on_failed_trial, callbacks, max_concurrent_trials, queue_trials, loggers, _remote)
#     442                 export_formats=export_formats,
#     443                 max_failures=max_failures,
# --> 444                 restore=restore)
#     445     else:
#     446         logger.debug("Ignoring some parameters passed into tune.run.")
#
# ~/.local/lib/python3.7/site-packages/ray/tune/experiment.py in __init__(self, name, run, stop, time_budget_s, config, resources_per_trial, num_samples, local_dir, sync_config, trial_name_creator, trial_dirname_creator, log_to_file, checkpoint_freq, checkpoint_at_end, keep_checkpoints_num, checkpoint_score_attr, export_formats, max_failures, restore)
#     111                     "checkpointable function. You can specify checkpoints "
#     112                     "within your trainable function.")
# --> 113         self._run_identifier = Experiment.register_if_needed(run)
#     114         self.name = name or self._run_identifier
#     115
#
# ~/.local/lib/python3.7/site-packages/ray/tune/experiment.py in register_if_needed(cls, run_object)
#     263                              "\n-If the error is typing-related, try removing "
#     264                              "the type annotations and try again.")
# --> 265                 raise type(e)(str(e) + " " + extra_msg) from None
#     266             return name
#     267         else:
#
# TypeError: ray.cloudpickle.dumps(<class 'ray.tune.function_runner.wrap_function.<locals>.ImplicitFunc'>) failed.
# To check which non-serializable variables are captured in scope, re-run the ray script with 'RAY_PICKLE_VERBOSE_DEBUG=1'. Other options:
# -Try reproducing the issue by calling `pickle.dumps(trainable)`.
# -If the error is typing-related, try removing the type annotations and try again.
